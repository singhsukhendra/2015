# %% [markdown]
# <a href="https://colab.research.google.com/github/singhsukhendra/2015/blob/master/Baseline_CNN_on_Pneumonia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D , MaxPool2D , Flatten , Dropout , BatchNormalization, GlobalAveragePooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,confusion_matrix
from tensorflow.keras.callbacks import ReduceLROnPlateau
import cv2
import os

# %%
labels = ['PNEUMONIA', 'NORMAL']
img_size = 150

# %%
import os
initial_count = 0
dir = "/content/drive/MyDrive/data/PNEUMONIA"
for path in os.listdir(dir):
    if os.path.isfile(os.path.join(dir, path)):
        initial_count += 1
print(initial_count)
# Out:
# 4273

# %%
import os
initial_count = 0
dir = "/content/drive/MyDrive/data/NORMAL"
for path in os.listdir(dir):
    if os.path.isfile(os.path.join(dir, path)):
        initial_count += 1
print(initial_count)
# Out:
# 1583

# %%
'''
def get_training_data(data_dir):
    data = [] 
    for label in labels: 
        path = os.path.join(data_dir, label)
        class_num = labels.index(label)
        for img in os.listdir(path):
            try:
                img_arr = cv2.imread(os.path.join(path, img), cv2.IMREAD_GRAYSCALE)
                resized_arr = cv2.resize(img_arr, (img_size, img_size)) # Reshaping images to preferred size
                data.append([resized_arr, class_num])
            except Exception as e:
                print(str(e))
    return np.array(data)
  
data = get_training_data('drive/MyDrive/data/')
np.save('data.npy', data, allow_pickle=True)
'''
# Out:
# "\ndef get_training_data(data_dir):\n    data = [] \n    for label in labels: \n        path = os.path.join(data_dir, label)\n        class_num = labels.index(label)\n        for img in os.listdir(path):\n            try:\n                img_arr = cv2.imread(os.path.join(path, img), cv2.IMREAD_GRAYSCALE)\n                resized_arr = cv2.resize(img_arr, (img_size, img_size)) # Reshaping images to preferred size\n                data.append([resized_arr, class_num])\n            except Exception as e:\n                print(str(e))\n    return np.array(data)\n  \ndata = get_training_data('drive/MyDrive/data/')\nnp.save('data.npy', data, allow_pickle=True)\n"

# %%
# If you've already ran the previous code block, run this one instead.
data = np.load('drive/MyDrive/data/data.npy', allow_pickle=True)

# %%
# Shuffle dataset
np.random.seed(1337)
np.random.shuffle(data)

# %%
train, val, test = np.split(data, [int(.75*len(data)), int(.80*len(data))])

# %%
len(train),len(val),len(test)
# Out:
# (4392, 292, 1172)

# %%
fig, ax = plt.subplots(3, 2, figsize=(6,10), facecolor='white')
for idx, item in enumerate(np.random.randint(0, train.shape[0], 6)):
    ax[int(idx/2)][idx%2].imshow(train[item][0], cmap='gray')
    ax[int(idx/2)][idx%2].set_title(labels[train[item][1]])
    ax[int(idx/2)][idx%2].axis('off')

# %%
print(data.shape)
print(train.shape, val.shape, test.shape)
# Out:
# (5856, 2)
# (4392, 2) (292, 2) (1172, 2)

# %%
# Train set splits
unique, counts = np.unique(train[:, 1], return_counts=True)
print(np.asarray((unique, counts)).T)
# Out:
# [[0 3205]
#  [1 1187]]

# %%
# Test set splits
unique, counts = np.unique(test[:, 1], return_counts=True)
print(np.asarray((unique, counts)).T)
# Out:
# [[0 842]
#  [1 330]]

# %%
# Validation set splits
unique, counts = np.unique(val[:, 1], return_counts=True)
print(np.asarray((unique, counts)).T)
# Out:
# [[0 226]
#  [1 66]]

# %%
unique, counts = np.unique(data[:, 1], return_counts=True)
print(np.asarray((unique, counts)).T)
# Out:
# [[0 4273]
#  [1 1583]]

# %%
x_train = []
y_train = []

x_val = []
y_val = []

x_test = []
y_test = []

for feature, label in train:
    x_train.append(feature)
    y_train.append(label)

for feature, label in test:
    x_test.append(feature)
    y_test.append(label)
    
for feature, label in val:
    x_val.append(feature)
    y_val.append(label)

# %%
l = []
for i in data:
    if(i[1] == 0):
        l.append("PNEUMONIA")
    else:
        l.append("NORMAL")
sns.set_style('darkgrid')
sns.countplot(l)

# %%
# Normalize data. Pixels are [0, 255], so dividing will place them into a [0, 1] range.
x_train = np.array(x_train) / 255
x_val = np.array(x_val) / 255
x_test = np.array(x_test) / 255

# %%
# Resize all images into a common size of 150 x 150
x_train = x_train.reshape(-1, img_size, img_size, 1)
y_train = np.array(y_train)

x_val = x_val.reshape(-1, img_size, img_size, 1)
y_val = np.array(y_val)

x_test = x_test.reshape(-1, img_size, img_size, 1)
y_test = np.array(y_test)

# %%
print(x_train[0].shape, x_train.shape, y_train.shape, x_val.shape, y_val.shape, x_test.shape, y_test.shape)
# Out:
# (150, 150, 1) (4392, 150, 150, 1) (4392,) (292, 150, 150, 1) (292,) (1172, 150, 150, 1) (1172,)

# %%
# Data augmentation to prevent overfitting and handling the imbalance in dataset
datagen = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range = 30,  # randomly rotate images in the range (degrees, 0 to 180)
        zoom_range = 0.2, # Randomly zoom image 
        width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
        horizontal_flip = True,  # randomly flip images
        vertical_flip=False)  # randomly flip images

datagen.fit(x_train)

# %%
def create_model():
    model = Sequential()
    model.add(Conv2D(32 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu' , input_shape = (150,150,1)))
    model.add(BatchNormalization())
   
    
    model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))

    model.add(Conv2D(64 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
    model.add(Dropout(0.1))
    model.add(BatchNormalization())
    
    
    model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))

    model.add(Conv2D(64 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
    model.add(BatchNormalization())
    
    model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))

    model.add(Conv2D(128 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
    model.add(Dropout(0.2))
    model.add(BatchNormalization())
    
    model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))

    model.add(Conv2D(256 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
    model.add(Dropout(0.2))
    model.add(BatchNormalization())
    
    model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))

    model.add(GlobalAveragePooling2D())
    model.add(Dense(units = 128 , activation = 'relu'))
    model.add(Dropout(0.2))
    model.add(Dense(units = 1 , activation = 'sigmoid'))
    
    return model

# %%
n_epoch = 50
lr = 0.001
batchsz = 32


METRICS = [
      tf.keras.metrics.TruePositives(name='tp'),
      tf.keras.metrics.FalsePositives(name='fp'),
      tf.keras.metrics.TrueNegatives(name='tn'),
      tf.keras.metrics.FalseNegatives(name='fn'), 
      tf.keras.metrics.BinaryAccuracy(name='accuracy'),
      tf.keras.metrics.Precision(name='precision'),
      tf.keras.metrics.Recall(name='recall'),
      tf.keras.metrics.AUC(name='roc', curve='ROC'), # roc curve
      tf.keras.metrics.AUC(name='prc', curve='PR') # precision-recall curve
]

# %%
optim = tf.keras.optimizers.Adam(lr=lr)
model = create_model()
model.compile(optimizer = optim, loss = 'binary_crossentropy', metrics = METRICS)

learning_rate_reduction = ReduceLROnPlateau(
    monitor='val_accuracy', patience=2, verbose=1, factor=0.8
)

history = model.fit(
    datagen.flow(x_train, y_train, batch_size=batchsz), 
    epochs = n_epoch, 
    validation_data = datagen.flow(x_val, y_val),
    callbacks = [learning_rate_reduction]
)
# Out:
# Epoch 1/50
# 138/138 [==============================] - 27s 112ms/step - loss: 0.2867 - tp: 931.0000 - fp: 281.0000 - tn: 2924.0000 - fn: 256.0000 - accuracy: 0.8777 - precision: 0.7682 - recall: 0.7843 - roc: 0.9350 - prc: 0.8257 - val_loss: 1.9981 - val_tp: 0.0000e+00 - val_fp: 0.0000e+00 - val_tn: 226.0000 - val_fn: 66.0000 - val_accuracy: 0.7740 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_roc: 0.5000 - val_prc: 0.2260 - lr: 0.0010
# Epoch 2/50
# 138/138 [==============================] - 14s 99ms/step - loss: 0.2303 - tp: 983.0000 - fp: 202.0000 - tn: 3003.0000 - fn: 204.0000 - accuracy: 0.9076 - precision: 0.8295 - recall: 0.8281 - roc: 0.9578 - prc: 0.8926 - val_loss: 2.1397 - val_tp: 0.0000e+00 - val_fp: 0.0000e+00 - val_tn: 226.0000 - val_fn: 66.0000 - val_accuracy: 0.7740 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_roc: 0.5000 - val_prc: 0.2260 - lr: 0.0010
# Epoch 3/50
# 138/138 [==============================] - ETA: 0s - loss: 0.2207 - tp: 998.0000 - fp: 193.0000 - tn: 3012.0000 - fn: 189.0000 - accuracy: 0.9130 - precision: 0.8380 - recall: 0.8408 - roc: 0.9602 - prc: 0.9117
# Epoch 00003: ReduceLROnPlateau reducing learning rate to 0.000800000037997961.
# 138/138 [==============================] - 14s 100ms/step - loss: 0.2207 - tp: 998.0000 - fp: 193.0000 - tn: 3012.0000 - fn: 189.0000 - accuracy: 0.9130 - precision: 0.8380 - recall: 0.8408 - roc: 0.9602 - prc: 0.9117 - val_loss: 2.0658 - val_tp: 0.0000e+00 - val_fp: 0.0000e+00 - val_tn: 226.0000 - val_fn: 66.0000 - val_accuracy: 0.7740 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_roc: 0.5000 - val_prc: 0.2260 - lr: 0.0010
# Epoch 4/50
# 138/138 [==============================] - 14s 100ms/step - loss: 0.2020 - tp: 1005.0000 - fp: 175.0000 - tn: 3030.0000 - fn: 182.0000 - accuracy: 0.9187 - precision: 0.8517 - recall: 0.8467 - roc: 0.9665 - prc: 0.9234 - val_loss: 1.5058 - val_tp: 0.0000e+00 - val_fp: 0.0000e+00 - val_tn: 226.0000 - val_fn: 66.0000 - val_accuracy: 0.7740 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_roc: 0.6190 - val_prc: 0.4619 - lr: 8.0000e-04
# Epoch 5/50
# 138/138 [==============================] - ETA: 0s - loss: 0.1875 - tp: 1017.0000 - fp: 159.0000 - tn: 3046.0000 - fn: 170.0000 - accuracy: 0.9251 - precision: 0.8648 - recall: 0.8568 - roc: 0.9704 - prc: 0.9364
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.0006400000303983689.
# 138/138 [==============================] - 14s 98ms/step - loss: 0.1875 - tp: 1017.0000 - fp: 159.0000 - tn: 3046.0000 - fn: 170.0000 - accuracy: 0.9251 - precision: 0.8648 - recall: 0.8568 - roc: 0.9704 - prc: 0.9364 - val_loss: 1.2303 - val_tp: 0.0000e+00 - val_fp: 0.0000e+00 - val_tn: 226.0000 - val_fn: 66.0000 - val_accuracy: 0.7740 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_roc: 0.6952 - val_prc: 0.5466 - lr: 8.0000e-04
# Epoch 6/50
# 138/138 [==============================] - 14s 98ms/step - loss: 0.1711 - tp: 1036.0000 - fp: 133.0000 - tn: 3072.0000 - fn: 151.0000 - accuracy: 0.9353 - precision: 0.8862 - recall: 0.8728 - roc: 0.9750 - prc: 0.9461 - val_loss: 0.2677 - val_tp: 34.0000 - val_fp: 1.0000 - val_tn: 225.0000 - val_fn: 32.0000 - val_accuracy: 0.8870 - val_precision: 0.9714 - val_recall: 0.5152 - val_roc: 0.9722 - val_prc: 0.9149 - lr: 6.4000e-04
# Epoch 7/50
# 138/138 [==============================] - 14s 98ms/step - loss: 0.1781 - tp: 1038.0000 - fp: 129.0000 - tn: 3076.0000 - fn: 149.0000 - accuracy: 0.9367 - precision: 0.8895 - recall: 0.8745 - roc: 0.9725 - prc: 0.9390 - val_loss: 0.1542 - val_tp: 58.0000 - val_fp: 8.0000 - val_tn: 218.0000 - val_fn: 8.0000 - val_accuracy: 0.9452 - val_precision: 0.8788 - val_recall: 0.8788 - val_roc: 0.9833 - val_prc: 0.9396 - lr: 6.4000e-04
# Epoch 8/50
# 138/138 [==============================] - 14s 98ms/step - loss: 0.1697 - tp: 1032.0000 - fp: 122.0000 - tn: 3083.0000 - fn: 155.0000 - accuracy: 0.9369 - precision: 0.8943 - recall: 0.8694 - roc: 0.9762 - prc: 0.9445 - val_loss: 0.7627 - val_tp: 0.0000e+00 - val_fp: 0.0000e+00 - val_tn: 226.0000 - val_fn: 66.0000 - val_accuracy: 0.7740 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_roc: 0.4872 - val_prc: 0.2211 - lr: 6.4000e-04
# Epoch 9/50
# 138/138 [==============================] - ETA: 0s - loss: 0.1719 - tp: 1027.0000 - fp: 126.0000 - tn: 3079.0000 - fn: 160.0000 - accuracy: 0.9349 - precision: 0.8907 - recall: 0.8652 - roc: 0.9756 - prc: 0.9399
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 0.0005120000336319208.
# 138/138 [==============================] - 13s 97ms/step - loss: 0.1719 - tp: 1027.0000 - fp: 126.0000 - tn: 3079.0000 - fn: 160.0000 - accuracy: 0.9349 - precision: 0.8907 - recall: 0.8652 - roc: 0.9756 - prc: 0.9399 - val_loss: 2.0672 - val_tp: 66.0000 - val_fp: 177.0000 - val_tn: 49.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.3938 - val_precision: 0.2716 - val_recall: 1.0000 - val_roc: 0.9281 - val_prc: 0.7184 - lr: 6.4000e-04
# Epoch 10/50
# 138/138 [==============================] - 14s 99ms/step - loss: 0.1560 - tp: 1056.0000 - fp: 126.0000 - tn: 3079.0000 - fn: 131.0000 - accuracy: 0.9415 - precision: 0.8934 - recall: 0.8896 - roc: 0.9794 - prc: 0.9538 - val_loss: 2.1879 - val_tp: 66.0000 - val_fp: 189.0000 - val_tn: 37.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.3527 - val_precision: 0.2588 - val_recall: 1.0000 - val_roc: 0.5993 - val_prc: 0.2451 - lr: 5.1200e-04
# Epoch 11/50
# 138/138 [==============================] - ETA: 0s - loss: 0.1508 - tp: 1066.0000 - fp: 104.0000 - tn: 3101.0000 - fn: 121.0000 - accuracy: 0.9488 - precision: 0.9111 - recall: 0.8981 - roc: 0.9797 - prc: 0.9556
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.00040960004553198815.
# 138/138 [==============================] - 14s 98ms/step - loss: 0.1508 - tp: 1066.0000 - fp: 104.0000 - tn: 3101.0000 - fn: 121.0000 - accuracy: 0.9488 - precision: 0.9111 - recall: 0.8981 - roc: 0.9797 - prc: 0.9556 - val_loss: 0.1988 - val_tp: 43.0000 - val_fp: 2.0000 - val_tn: 224.0000 - val_fn: 23.0000 - val_accuracy: 0.9144 - val_precision: 0.9556 - val_recall: 0.6515 - val_roc: 0.9737 - val_prc: 0.9319 - lr: 5.1200e-04
# Epoch 12/50
# 138/138 [==============================] - 14s 98ms/step - loss: 0.1532 - tp: 1057.0000 - fp: 126.0000 - tn: 3079.0000 - fn: 130.0000 - accuracy: 0.9417 - precision: 0.8935 - recall: 0.8905 - roc: 0.9805 - prc: 0.9517 - val_loss: 1.2707 - val_tp: 0.0000e+00 - val_fp: 0.0000e+00 - val_tn: 226.0000 - val_fn: 66.0000 - val_accuracy: 0.7740 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_roc: 0.7420 - val_prc: 0.6589 - lr: 4.0960e-04
# Epoch 13/50
# 138/138 [==============================] - ETA: 0s - loss: 0.1448 - tp: 1050.0000 - fp: 106.0000 - tn: 3099.0000 - fn: 137.0000 - accuracy: 0.9447 - precision: 0.9083 - recall: 0.8846 - roc: 0.9822 - prc: 0.9590
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 0.00032768002711236477.
# 138/138 [==============================] - 14s 99ms/step - loss: 0.1448 - tp: 1050.0000 - fp: 106.0000 - tn: 3099.0000 - fn: 137.0000 - accuracy: 0.9447 - precision: 0.9083 - recall: 0.8846 - roc: 0.9822 - prc: 0.9590 - val_loss: 0.6984 - val_tp: 65.0000 - val_fp: 93.0000 - val_tn: 133.0000 - val_fn: 1.0000 - val_accuracy: 0.6781 - val_precision: 0.4114 - val_recall: 0.9848 - val_roc: 0.8485 - val_prc: 0.5078 - lr: 4.0960e-04
# Epoch 14/50
# 138/138 [==============================] - 14s 98ms/step - loss: 0.1357 - tp: 1067.0000 - fp: 106.0000 - tn: 3099.0000 - fn: 120.0000 - accuracy: 0.9485 - precision: 0.9096 - recall: 0.8989 - roc: 0.9843 - prc: 0.9637 - val_loss: 1.1527 - val_tp: 66.0000 - val_fp: 128.0000 - val_tn: 98.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.5616 - val_precision: 0.3402 - val_recall: 1.0000 - val_roc: 0.8906 - val_prc: 0.6347 - lr: 3.2768e-04
# Epoch 15/50
# 138/138 [==============================] - ETA: 0s - loss: 0.1327 - tp: 1075.0000 - fp: 102.0000 - tn: 3103.0000 - fn: 112.0000 - accuracy: 0.9513 - precision: 0.9133 - recall: 0.9056 - roc: 0.9851 - prc: 0.9626
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.0002621440216898918.
# 138/138 [==============================] - 14s 98ms/step - loss: 0.1327 - tp: 1075.0000 - fp: 102.0000 - tn: 3103.0000 - fn: 112.0000 - accuracy: 0.9513 - precision: 0.9133 - recall: 0.9056 - roc: 0.9851 - prc: 0.9626 - val_loss: 0.7812 - val_tp: 66.0000 - val_fp: 98.0000 - val_tn: 128.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.6644 - val_precision: 0.4024 - val_recall: 1.0000 - val_roc: 0.9678 - val_prc: 0.8677 - lr: 3.2768e-04
# Epoch 16/50
# 138/138 [==============================] - 14s 99ms/step - loss: 0.1280 - tp: 1078.0000 - fp: 107.0000 - tn: 3098.0000 - fn: 109.0000 - accuracy: 0.9508 - precision: 0.9097 - recall: 0.9082 - roc: 0.9861 - prc: 0.9675 - val_loss: 0.2747 - val_tp: 38.0000 - val_fp: 1.0000 - val_tn: 225.0000 - val_fn: 28.0000 - val_accuracy: 0.9007 - val_precision: 0.9744 - val_recall: 0.5758 - val_roc: 0.9622 - val_prc: 0.9334 - lr: 2.6214e-04
# Epoch 17/50
# 138/138 [==============================] - 14s 99ms/step - loss: 0.1222 - tp: 1085.0000 - fp: 82.0000 - tn: 3123.0000 - fn: 102.0000 - accuracy: 0.9581 - precision: 0.9297 - recall: 0.9141 - roc: 0.9868 - prc: 0.9695 - val_loss: 0.1026 - val_tp: 58.0000 - val_fp: 1.0000 - val_tn: 225.0000 - val_fn: 8.0000 - val_accuracy: 0.9692 - val_precision: 0.9831 - val_recall: 0.8788 - val_roc: 0.9906 - val_prc: 0.9790 - lr: 2.6214e-04
# Epoch 18/50
# 138/138 [==============================] - 14s 101ms/step - loss: 0.1210 - tp: 1084.0000 - fp: 92.0000 - tn: 3113.0000 - fn: 103.0000 - accuracy: 0.9556 - precision: 0.9218 - recall: 0.9132 - roc: 0.9875 - prc: 0.9708 - val_loss: 0.2132 - val_tp: 39.0000 - val_fp: 1.0000 - val_tn: 225.0000 - val_fn: 27.0000 - val_accuracy: 0.9041 - val_precision: 0.9750 - val_recall: 0.5909 - val_roc: 0.9879 - val_prc: 0.9605 - lr: 2.6214e-04
# Epoch 19/50
# 138/138 [==============================] - ETA: 0s - loss: 0.1249 - tp: 1072.0000 - fp: 86.0000 - tn: 3119.0000 - fn: 115.0000 - accuracy: 0.9542 - precision: 0.9257 - recall: 0.9031 - roc: 0.9863 - prc: 0.9683
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 0.00020971521735191345.
# 138/138 [==============================] - 14s 102ms/step - loss: 0.1249 - tp: 1072.0000 - fp: 86.0000 - tn: 3119.0000 - fn: 115.0000 - accuracy: 0.9542 - precision: 0.9257 - recall: 0.9031 - roc: 0.9863 - prc: 0.9683 - val_loss: 1.4025 - val_tp: 66.0000 - val_fp: 123.0000 - val_tn: 103.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.5788 - val_precision: 0.3492 - val_recall: 1.0000 - val_roc: 0.9434 - val_prc: 0.7455 - lr: 2.6214e-04
# Epoch 20/50
# 138/138 [==============================] - 14s 100ms/step - loss: 0.1163 - tp: 1088.0000 - fp: 88.0000 - tn: 3117.0000 - fn: 99.0000 - accuracy: 0.9574 - precision: 0.9252 - recall: 0.9166 - roc: 0.9882 - prc: 0.9730 - val_loss: 0.1275 - val_tp: 51.0000 - val_fp: 1.0000 - val_tn: 225.0000 - val_fn: 15.0000 - val_accuracy: 0.9452 - val_precision: 0.9808 - val_recall: 0.7727 - val_roc: 0.9905 - val_prc: 0.9605 - lr: 2.0972e-04
# Epoch 21/50
# 138/138 [==============================] - ETA: 0s - loss: 0.1073 - tp: 1092.0000 - fp: 74.0000 - tn: 3131.0000 - fn: 95.0000 - accuracy: 0.9615 - precision: 0.9365 - recall: 0.9200 - roc: 0.9904 - prc: 0.9767
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 0.00016777217388153076.
# 138/138 [==============================] - 14s 100ms/step - loss: 0.1073 - tp: 1092.0000 - fp: 74.0000 - tn: 3131.0000 - fn: 95.0000 - accuracy: 0.9615 - precision: 0.9365 - recall: 0.9200 - roc: 0.9904 - prc: 0.9767 - val_loss: 0.1106 - val_tp: 57.0000 - val_fp: 2.0000 - val_tn: 224.0000 - val_fn: 9.0000 - val_accuracy: 0.9623 - val_precision: 0.9661 - val_recall: 0.8636 - val_roc: 0.9910 - val_prc: 0.9605 - lr: 2.0972e-04
# Epoch 22/50
# 138/138 [==============================] - 14s 99ms/step - loss: 0.1205 - tp: 1067.0000 - fp: 90.0000 - tn: 3115.0000 - fn: 120.0000 - accuracy: 0.9522 - precision: 0.9222 - recall: 0.8989 - roc: 0.9874 - prc: 0.9720 - val_loss: 0.1290 - val_tp: 65.0000 - val_fp: 13.0000 - val_tn: 213.0000 - val_fn: 1.0000 - val_accuracy: 0.9521 - val_precision: 0.8333 - val_recall: 0.9848 - val_roc: 0.9903 - val_prc: 0.9696 - lr: 1.6777e-04
# Epoch 23/50
# 138/138 [==============================] - ETA: 0s - loss: 0.1112 - tp: 1092.0000 - fp: 84.0000 - tn: 3121.0000 - fn: 95.0000 - accuracy: 0.9592 - precision: 0.9286 - recall: 0.9200 - roc: 0.9895 - prc: 0.9753
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 0.00013421773910522462.
# 138/138 [==============================] - 14s 98ms/step - loss: 0.1112 - tp: 1092.0000 - fp: 84.0000 - tn: 3121.0000 - fn: 95.0000 - accuracy: 0.9592 - precision: 0.9286 - recall: 0.9200 - roc: 0.9895 - prc: 0.9753 - val_loss: 0.1671 - val_tp: 65.0000 - val_fp: 17.0000 - val_tn: 209.0000 - val_fn: 1.0000 - val_accuracy: 0.9384 - val_precision: 0.7927 - val_recall: 0.9848 - val_roc: 0.9909 - val_prc: 0.9558 - lr: 1.6777e-04
# Epoch 24/50
# 138/138 [==============================] - 14s 98ms/step - loss: 0.1046 - tp: 1093.0000 - fp: 74.0000 - tn: 3131.0000 - fn: 94.0000 - accuracy: 0.9617 - precision: 0.9366 - recall: 0.9208 - roc: 0.9906 - prc: 0.9769 - val_loss: 0.2053 - val_tp: 38.0000 - val_fp: 0.0000e+00 - val_tn: 226.0000 - val_fn: 28.0000 - val_accuracy: 0.9041 - val_precision: 1.0000 - val_recall: 0.5758 - val_roc: 0.9932 - val_prc: 0.9775 - lr: 1.3422e-04
# Epoch 25/50
# 138/138 [==============================] - ETA: 0s - loss: 0.1036 - tp: 1093.0000 - fp: 80.0000 - tn: 3125.0000 - fn: 94.0000 - accuracy: 0.9604 - precision: 0.9318 - recall: 0.9208 - roc: 0.9911 - prc: 0.9790
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 0.00010737419361248613.
# 138/138 [==============================] - 14s 100ms/step - loss: 0.1036 - tp: 1093.0000 - fp: 80.0000 - tn: 3125.0000 - fn: 94.0000 - accuracy: 0.9604 - precision: 0.9318 - recall: 0.9208 - roc: 0.9911 - prc: 0.9790 - val_loss: 0.0815 - val_tp: 58.0000 - val_fp: 3.0000 - val_tn: 223.0000 - val_fn: 8.0000 - val_accuracy: 0.9623 - val_precision: 0.9508 - val_recall: 0.8788 - val_roc: 0.9949 - val_prc: 0.9839 - lr: 1.3422e-04
# Epoch 26/50
# 138/138 [==============================] - 14s 99ms/step - loss: 0.0938 - tp: 1105.0000 - fp: 72.0000 - tn: 3133.0000 - fn: 82.0000 - accuracy: 0.9649 - precision: 0.9388 - recall: 0.9309 - roc: 0.9927 - prc: 0.9823 - val_loss: 0.0933 - val_tp: 61.0000 - val_fp: 3.0000 - val_tn: 223.0000 - val_fn: 5.0000 - val_accuracy: 0.9726 - val_precision: 0.9531 - val_recall: 0.9242 - val_roc: 0.9931 - val_prc: 0.9730 - lr: 1.0737e-04
# Epoch 27/50
# 138/138 [==============================] - 14s 101ms/step - loss: 0.0993 - tp: 1103.0000 - fp: 74.0000 - tn: 3131.0000 - fn: 84.0000 - accuracy: 0.9640 - precision: 0.9371 - recall: 0.9292 - roc: 0.9914 - prc: 0.9790 - val_loss: 0.0727 - val_tp: 62.0000 - val_fp: 5.0000 - val_tn: 221.0000 - val_fn: 4.0000 - val_accuracy: 0.9692 - val_precision: 0.9254 - val_recall: 0.9394 - val_roc: 0.9961 - val_prc: 0.9872 - lr: 1.0737e-04
# Epoch 28/50
# 138/138 [==============================] - 14s 98ms/step - loss: 0.0933 - tp: 1107.0000 - fp: 64.0000 - tn: 3141.0000 - fn: 80.0000 - accuracy: 0.9672 - precision: 0.9453 - recall: 0.9326 - roc: 0.9917 - prc: 0.9813 - val_loss: 0.0661 - val_tp: 61.0000 - val_fp: 2.0000 - val_tn: 224.0000 - val_fn: 5.0000 - val_accuracy: 0.9760 - val_precision: 0.9683 - val_recall: 0.9242 - val_roc: 0.9961 - val_prc: 0.9841 - lr: 1.0737e-04
# Epoch 29/50
# 138/138 [==============================] - 14s 99ms/step - loss: 0.0948 - tp: 1108.0000 - fp: 71.0000 - tn: 3134.0000 - fn: 79.0000 - accuracy: 0.9658 - precision: 0.9398 - recall: 0.9334 - roc: 0.9919 - prc: 0.9819 - val_loss: 0.1156 - val_tp: 59.0000 - val_fp: 3.0000 - val_tn: 223.0000 - val_fn: 7.0000 - val_accuracy: 0.9658 - val_precision: 0.9516 - val_recall: 0.8939 - val_roc: 0.9884 - val_prc: 0.9629 - lr: 1.0737e-04
# Epoch 30/50
# 138/138 [==============================] - ETA: 0s - loss: 0.0961 - tp: 1105.0000 - fp: 70.0000 - tn: 3135.0000 - fn: 82.0000 - accuracy: 0.9654 - precision: 0.9404 - recall: 0.9309 - roc: 0.9922 - prc: 0.9807
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 8.589935605414213e-05.
# 138/138 [==============================] - 14s 101ms/step - loss: 0.0961 - tp: 1105.0000 - fp: 70.0000 - tn: 3135.0000 - fn: 82.0000 - accuracy: 0.9654 - precision: 0.9404 - recall: 0.9309 - roc: 0.9922 - prc: 0.9807 - val_loss: 0.2001 - val_tp: 65.0000 - val_fp: 19.0000 - val_tn: 207.0000 - val_fn: 1.0000 - val_accuracy: 0.9315 - val_precision: 0.7738 - val_recall: 0.9848 - val_roc: 0.9925 - val_prc: 0.9768 - lr: 1.0737e-04
# Epoch 31/50
# 138/138 [==============================] - 14s 99ms/step - loss: 0.0997 - tp: 1102.0000 - fp: 68.0000 - tn: 3137.0000 - fn: 85.0000 - accuracy: 0.9652 - precision: 0.9419 - recall: 0.9284 - roc: 0.9909 - prc: 0.9795 - val_loss: 0.2051 - val_tp: 65.0000 - val_fp: 26.0000 - val_tn: 200.0000 - val_fn: 1.0000 - val_accuracy: 0.9075 - val_precision: 0.7143 - val_recall: 0.9848 - val_roc: 0.9934 - val_prc: 0.9820 - lr: 8.5899e-05
# Epoch 32/50
# 138/138 [==============================] - ETA: 0s - loss: 0.0856 - tp: 1113.0000 - fp: 64.0000 - tn: 3141.0000 - fn: 74.0000 - accuracy: 0.9686 - precision: 0.9456 - recall: 0.9377 - roc: 0.9941 - prc: 0.9839
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 6.871948717162013e-05.
# 138/138 [==============================] - 14s 98ms/step - loss: 0.0856 - tp: 1113.0000 - fp: 64.0000 - tn: 3141.0000 - fn: 74.0000 - accuracy: 0.9686 - precision: 0.9456 - recall: 0.9377 - roc: 0.9941 - prc: 0.9839 - val_loss: 0.2084 - val_tp: 43.0000 - val_fp: 0.0000e+00 - val_tn: 226.0000 - val_fn: 23.0000 - val_accuracy: 0.9212 - val_precision: 1.0000 - val_recall: 0.6515 - val_roc: 0.9862 - val_prc: 0.9727 - lr: 8.5899e-05
# Epoch 33/50
# 138/138 [==============================] - 13s 97ms/step - loss: 0.0830 - tp: 1108.0000 - fp: 57.0000 - tn: 3148.0000 - fn: 79.0000 - accuracy: 0.9690 - precision: 0.9511 - recall: 0.9334 - roc: 0.9945 - prc: 0.9863 - val_loss: 0.1067 - val_tp: 66.0000 - val_fp: 9.0000 - val_tn: 217.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.9692 - val_precision: 0.8800 - val_recall: 1.0000 - val_roc: 0.9954 - val_prc: 0.9824 - lr: 6.8719e-05
# Epoch 34/50
# 138/138 [==============================] - ETA: 0s - loss: 0.0881 - tp: 1109.0000 - fp: 68.0000 - tn: 3137.0000 - fn: 78.0000 - accuracy: 0.9668 - precision: 0.9422 - recall: 0.9343 - roc: 0.9935 - prc: 0.9838
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 5.497558740898967e-05.
# 138/138 [==============================] - 14s 98ms/step - loss: 0.0881 - tp: 1109.0000 - fp: 68.0000 - tn: 3137.0000 - fn: 78.0000 - accuracy: 0.9668 - precision: 0.9422 - recall: 0.9343 - roc: 0.9935 - prc: 0.9838 - val_loss: 0.0920 - val_tp: 61.0000 - val_fp: 2.0000 - val_tn: 224.0000 - val_fn: 5.0000 - val_accuracy: 0.9760 - val_precision: 0.9683 - val_recall: 0.9242 - val_roc: 0.9927 - val_prc: 0.9654 - lr: 6.8719e-05
# Epoch 35/50
# 138/138 [==============================] - 14s 98ms/step - loss: 0.0872 - tp: 1112.0000 - fp: 68.0000 - tn: 3137.0000 - fn: 75.0000 - accuracy: 0.9674 - precision: 0.9424 - recall: 0.9368 - roc: 0.9936 - prc: 0.9850 - val_loss: 0.0856 - val_tp: 61.0000 - val_fp: 2.0000 - val_tn: 224.0000 - val_fn: 5.0000 - val_accuracy: 0.9760 - val_precision: 0.9683 - val_recall: 0.9242 - val_roc: 0.9930 - val_prc: 0.9746 - lr: 5.4976e-05
# Epoch 36/50
# 138/138 [==============================] - ETA: 0s - loss: 0.0905 - tp: 1107.0000 - fp: 68.0000 - tn: 3137.0000 - fn: 80.0000 - accuracy: 0.9663 - precision: 0.9421 - recall: 0.9326 - roc: 0.9933 - prc: 0.9827
# Epoch 00036: ReduceLROnPlateau reducing learning rate to 4.398046876303852e-05.
# 138/138 [==============================] - 14s 98ms/step - loss: 0.0905 - tp: 1107.0000 - fp: 68.0000 - tn: 3137.0000 - fn: 80.0000 - accuracy: 0.9663 - precision: 0.9421 - recall: 0.9326 - roc: 0.9933 - prc: 0.9827 - val_loss: 0.0881 - val_tp: 59.0000 - val_fp: 1.0000 - val_tn: 225.0000 - val_fn: 7.0000 - val_accuracy: 0.9726 - val_precision: 0.9833 - val_recall: 0.8939 - val_roc: 0.9929 - val_prc: 0.9810 - lr: 5.4976e-05
# Epoch 37/50
# 138/138 [==============================] - 14s 99ms/step - loss: 0.0784 - tp: 1119.0000 - fp: 69.0000 - tn: 3136.0000 - fn: 68.0000 - accuracy: 0.9688 - precision: 0.9419 - recall: 0.9427 - roc: 0.9944 - prc: 0.9878 - val_loss: 0.1396 - val_tp: 51.0000 - val_fp: 1.0000 - val_tn: 225.0000 - val_fn: 15.0000 - val_accuracy: 0.9452 - val_precision: 0.9808 - val_recall: 0.7727 - val_roc: 0.9863 - val_prc: 0.9709 - lr: 4.3980e-05
# Epoch 38/50
# 138/138 [==============================] - ETA: 0s - loss: 0.0857 - tp: 1107.0000 - fp: 53.0000 - tn: 3152.0000 - fn: 80.0000 - accuracy: 0.9697 - precision: 0.9543 - recall: 0.9326 - roc: 0.9937 - prc: 0.9858
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 3.518437442835421e-05.
# 138/138 [==============================] - 14s 100ms/step - loss: 0.0857 - tp: 1107.0000 - fp: 53.0000 - tn: 3152.0000 - fn: 80.0000 - accuracy: 0.9697 - precision: 0.9543 - recall: 0.9326 - roc: 0.9937 - prc: 0.9858 - val_loss: 0.2273 - val_tp: 39.0000 - val_fp: 0.0000e+00 - val_tn: 226.0000 - val_fn: 27.0000 - val_accuracy: 0.9075 - val_precision: 1.0000 - val_recall: 0.5909 - val_roc: 0.9916 - val_prc: 0.9750 - lr: 4.3980e-05
# Epoch 39/50
# 138/138 [==============================] - 14s 101ms/step - loss: 0.0838 - tp: 1110.0000 - fp: 55.0000 - tn: 3150.0000 - fn: 77.0000 - accuracy: 0.9699 - precision: 0.9528 - recall: 0.9351 - roc: 0.9939 - prc: 0.9858 - val_loss: 0.0820 - val_tp: 59.0000 - val_fp: 2.0000 - val_tn: 224.0000 - val_fn: 7.0000 - val_accuracy: 0.9692 - val_precision: 0.9672 - val_recall: 0.8939 - val_roc: 0.9949 - val_prc: 0.9843 - lr: 3.5184e-05
# Epoch 40/50
# 138/138 [==============================] - ETA: 0s - loss: 0.0822 - tp: 1111.0000 - fp: 62.0000 - tn: 3143.0000 - fn: 76.0000 - accuracy: 0.9686 - precision: 0.9471 - recall: 0.9360 - roc: 0.9946 - prc: 0.9842
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 2.8147498960606756e-05.
# 138/138 [==============================] - 14s 99ms/step - loss: 0.0822 - tp: 1111.0000 - fp: 62.0000 - tn: 3143.0000 - fn: 76.0000 - accuracy: 0.9686 - precision: 0.9471 - recall: 0.9360 - roc: 0.9946 - prc: 0.9842 - val_loss: 0.1080 - val_tp: 60.0000 - val_fp: 6.0000 - val_tn: 220.0000 - val_fn: 6.0000 - val_accuracy: 0.9589 - val_precision: 0.9091 - val_recall: 0.9091 - val_roc: 0.9922 - val_prc: 0.9743 - lr: 3.5184e-05
# Epoch 41/50
# 138/138 [==============================] - 14s 100ms/step - loss: 0.0887 - tp: 1115.0000 - fp: 66.0000 - tn: 3139.0000 - fn: 72.0000 - accuracy: 0.9686 - precision: 0.9441 - recall: 0.9393 - roc: 0.9927 - prc: 0.9832 - val_loss: 0.0880 - val_tp: 60.0000 - val_fp: 3.0000 - val_tn: 223.0000 - val_fn: 6.0000 - val_accuracy: 0.9692 - val_precision: 0.9524 - val_recall: 0.9091 - val_roc: 0.9943 - val_prc: 0.9776 - lr: 2.8147e-05
# Epoch 42/50
# 138/138 [==============================] - ETA: 0s - loss: 0.0851 - tp: 1117.0000 - fp: 58.0000 - tn: 3147.0000 - fn: 70.0000 - accuracy: 0.9709 - precision: 0.9506 - recall: 0.9410 - roc: 0.9939 - prc: 0.9829
# Epoch 00042: ReduceLROnPlateau reducing learning rate to 2.25179988774471e-05.
# 138/138 [==============================] - 14s 101ms/step - loss: 0.0851 - tp: 1117.0000 - fp: 58.0000 - tn: 3147.0000 - fn: 70.0000 - accuracy: 0.9709 - precision: 0.9506 - recall: 0.9410 - roc: 0.9939 - prc: 0.9829 - val_loss: 0.0841 - val_tp: 56.0000 - val_fp: 0.0000e+00 - val_tn: 226.0000 - val_fn: 10.0000 - val_accuracy: 0.9658 - val_precision: 1.0000 - val_recall: 0.8485 - val_roc: 0.9971 - val_prc: 0.9909 - lr: 2.8147e-05
# Epoch 43/50
# 138/138 [==============================] - 14s 100ms/step - loss: 0.0826 - tp: 1107.0000 - fp: 60.0000 - tn: 3145.0000 - fn: 80.0000 - accuracy: 0.9681 - precision: 0.9486 - recall: 0.9326 - roc: 0.9945 - prc: 0.9853 - val_loss: 0.0746 - val_tp: 61.0000 - val_fp: 2.0000 - val_tn: 224.0000 - val_fn: 5.0000 - val_accuracy: 0.9760 - val_precision: 0.9683 - val_recall: 0.9242 - val_roc: 0.9955 - val_prc: 0.9855 - lr: 2.2518e-05
# Epoch 44/50
# 138/138 [==============================] - ETA: 0s - loss: 0.0842 - tp: 1121.0000 - fp: 73.0000 - tn: 3132.0000 - fn: 66.0000 - accuracy: 0.9684 - precision: 0.9389 - recall: 0.9444 - roc: 0.9944 - prc: 0.9856
# Epoch 00044: ReduceLROnPlateau reducing learning rate to 1.8014399392995985e-05.
# 138/138 [==============================] - 14s 100ms/step - loss: 0.0842 - tp: 1121.0000 - fp: 73.0000 - tn: 3132.0000 - fn: 66.0000 - accuracy: 0.9684 - precision: 0.9389 - recall: 0.9444 - roc: 0.9944 - prc: 0.9856 - val_loss: 0.0878 - val_tp: 58.0000 - val_fp: 1.0000 - val_tn: 225.0000 - val_fn: 8.0000 - val_accuracy: 0.9692 - val_precision: 0.9831 - val_recall: 0.8788 - val_roc: 0.9925 - val_prc: 0.9763 - lr: 2.2518e-05
# Epoch 45/50
# 138/138 [==============================] - 14s 100ms/step - loss: 0.0797 - tp: 1110.0000 - fp: 60.0000 - tn: 3145.0000 - fn: 77.0000 - accuracy: 0.9688 - precision: 0.9487 - recall: 0.9351 - roc: 0.9949 - prc: 0.9862 - val_loss: 0.0741 - val_tp: 59.0000 - val_fp: 2.0000 - val_tn: 224.0000 - val_fn: 7.0000 - val_accuracy: 0.9692 - val_precision: 0.9672 - val_recall: 0.8939 - val_roc: 0.9967 - val_prc: 0.9876 - lr: 1.8014e-05
# Epoch 46/50
# 138/138 [==============================] - ETA: 0s - loss: 0.0800 - tp: 1121.0000 - fp: 53.0000 - tn: 3152.0000 - fn: 66.0000 - accuracy: 0.9729 - precision: 0.9549 - recall: 0.9444 - roc: 0.9948 - prc: 0.9862
# Epoch 00046: ReduceLROnPlateau reducing learning rate to 1.4411519805435093e-05.
# 138/138 [==============================] - 14s 100ms/step - loss: 0.0800 - tp: 1121.0000 - fp: 53.0000 - tn: 3152.0000 - fn: 66.0000 - accuracy: 0.9729 - precision: 0.9549 - recall: 0.9444 - roc: 0.9948 - prc: 0.9862 - val_loss: 0.0761 - val_tp: 63.0000 - val_fp: 4.0000 - val_tn: 222.0000 - val_fn: 3.0000 - val_accuracy: 0.9760 - val_precision: 0.9403 - val_recall: 0.9545 - val_roc: 0.9940 - val_prc: 0.9828 - lr: 1.8014e-05
# Epoch 47/50
# 138/138 [==============================] - 14s 99ms/step - loss: 0.0753 - tp: 1127.0000 - fp: 61.0000 - tn: 3144.0000 - fn: 60.0000 - accuracy: 0.9724 - precision: 0.9487 - recall: 0.9495 - roc: 0.9954 - prc: 0.9863 - val_loss: 0.0702 - val_tp: 60.0000 - val_fp: 2.0000 - val_tn: 224.0000 - val_fn: 6.0000 - val_accuracy: 0.9726 - val_precision: 0.9677 - val_recall: 0.9091 - val_roc: 0.9965 - val_prc: 0.9878 - lr: 1.4412e-05
# Epoch 48/50
# 138/138 [==============================] - ETA: 0s - loss: 0.0762 - tp: 1121.0000 - fp: 55.0000 - tn: 3150.0000 - fn: 66.0000 - accuracy: 0.9724 - precision: 0.9532 - recall: 0.9444 - roc: 0.9947 - prc: 0.9858
# Epoch 00048: ReduceLROnPlateau reducing learning rate to 1.1529216135386379e-05.
# 138/138 [==============================] - 14s 100ms/step - loss: 0.0762 - tp: 1121.0000 - fp: 55.0000 - tn: 3150.0000 - fn: 66.0000 - accuracy: 0.9724 - precision: 0.9532 - recall: 0.9444 - roc: 0.9947 - prc: 0.9858 - val_loss: 0.0624 - val_tp: 61.0000 - val_fp: 2.0000 - val_tn: 224.0000 - val_fn: 5.0000 - val_accuracy: 0.9760 - val_precision: 0.9683 - val_recall: 0.9242 - val_roc: 0.9976 - val_prc: 0.9916 - lr: 1.4412e-05
# Epoch 49/50
# 138/138 [==============================] - 14s 102ms/step - loss: 0.0786 - tp: 1121.0000 - fp: 54.0000 - tn: 3151.0000 - fn: 66.0000 - accuracy: 0.9727 - precision: 0.9540 - recall: 0.9444 - roc: 0.9950 - prc: 0.9872 - val_loss: 0.0747 - val_tp: 61.0000 - val_fp: 3.0000 - val_tn: 223.0000 - val_fn: 5.0000 - val_accuracy: 0.9726 - val_precision: 0.9531 - val_recall: 0.9242 - val_roc: 0.9953 - val_prc: 0.9834 - lr: 1.1529e-05
# Epoch 50/50
# 138/138 [==============================] - ETA: 0s - loss: 0.0797 - tp: 1121.0000 - fp: 62.0000 - tn: 3143.0000 - fn: 66.0000 - accuracy: 0.9709 - precision: 0.9476 - recall: 0.9444 - roc: 0.9941 - prc: 0.9872
# Epoch 00050: ReduceLROnPlateau reducing learning rate to 9.223372762789951e-06.
# 138/138 [==============================] - 14s 103ms/step - loss: 0.0797 - tp: 1121.0000 - fp: 62.0000 - tn: 3143.0000 - fn: 66.0000 - accuracy: 0.9709 - precision: 0.9476 - recall: 0.9444 - roc: 0.9941 - prc: 0.9872 - val_loss: 0.0768 - val_tp: 58.0000 - val_fp: 1.0000 - val_tn: 225.0000 - val_fn: 8.0000 - val_accuracy: 0.9692 - val_precision: 0.9831 - val_recall: 0.8788 - val_roc: 0.9962 - val_prc: 0.9893 - lr: 1.1529e-05

# %%
results = model.evaluate(x_test,y_test)
# Out:
# 37/37 [==============================] - 2s 34ms/step - loss: 0.1073 - tp: 314.0000 - fp: 30.0000 - tn: 812.0000 - fn: 16.0000 - accuracy: 0.9608 - precision: 0.9128 - recall: 0.9515 - roc: 0.9927 - prc: 0.9843

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 150, 150, 32)      320
#
#  batch_normalization (BatchN  (None, 150, 150, 32)     128
#  ormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 75, 75, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 75, 75, 64)        18496
#
#  dropout (Dropout)           (None, 75, 75, 64)        0
#
#  batch_normalization_1 (Batc  (None, 75, 75, 64)       256
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 38, 38, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 38, 38, 64)        36928
#
#  batch_normalization_2 (Batc  (None, 38, 38, 64)       256
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 19, 19, 64)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 19, 19, 128)       73856
#
#  dropout_1 (Dropout)         (None, 19, 19, 128)       0
#
#  batch_normalization_3 (Batc  (None, 19, 19, 128)      512
#  hNormalization)
#
#  max_pooling2d_3 (MaxPooling  (None, 10, 10, 128)      0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 10, 10, 256)       295168
#
#  dropout_2 (Dropout)         (None, 10, 10, 256)       0
#
#  batch_normalization_4 (Batc  (None, 10, 10, 256)      1024
#  hNormalization)
#
#  max_pooling2d_4 (MaxPooling  (None, 5, 5, 256)        0
#  2D)
#
#  global_average_pooling2d (G  (None, 256)              0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 128)               32896
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 459,969
# Trainable params: 458,881
# Non-trainable params: 1,088
# _________________________________________________________________

# %%
len(model.layers)
# Out:
# 22

# %%
import pandas as pd



# convert the history.history dict to a pandas DataFrame:     
hist_df = pd.DataFrame(history.history) 

# save to json:  
hist_json_file = 'history.json' 
with open(hist_json_file, mode='w') as f:
    hist_df.to_json(f)

# or save to csv: 
hist_csv_file = 'history.csv'
with open(hist_csv_file, mode='w') as f:
    hist_df.to_csv(f)

# %%
print("Loss of the model is - " , results[0])
print("True positives of the model is - " , results[1])
print("False positives of the model is - " , results[2])
print("True negatives of the model is - " , results[3])
print("False negatives of the model is - " , results[4])
print("Accuracy of the model is - " , results[5]*100 , "%")
print("Precision of the model is - " , results[6])
print("Recall of the model is - " , results[7])
print("ROC_AUC of the model is - " , results[8])
print("PRC_AUC of the model is - " , results[9])
# Out:
# Loss of the model is -  0.10734228789806366
# True positives of the model is -  314.0
# False positives of the model is -  30.0
# True negatives of the model is -  812.0
# False negatives of the model is -  16.0
# Accuracy of the model is -  96.07508778572083 %
# Precision of the model is -  0.9127907156944275
# Recall of the model is -  0.9515151381492615
# ROC_AUC of the model is -  0.9926923513412476
# PRC_AUC of the model is -  0.9843103885650635

# %%
def plot_metrics(history):
    
    fig = plt.gcf()
    fig.set_size_inches(20, 3 * 4)

    metrics = ['roc','accuracy','loss', 'prc', 'precision', 'recall']
    for n, metric in enumerate(metrics):
        lims = {'loss': {0,2}}
        name = metric.replace("_"," ").capitalize()
        sp = plt.subplot(2, 3, n + 1)
        plt.plot(history.epoch, history.history[metric], color='C0', label='Train')
        plt.plot(history.epoch, history.history['val_'+metric],
                 color='C1', linestyle="--", label='Val')
        plt.xlabel('Epoch')
        plt.ylabel(name)
        if metric in lims:
            plt.ylim(lims[metric])

        plt.legend()

# %%
plot_metrics(history)

# %%
epochs = [i for i in range(50)]
fig , ax = plt.subplots(1,2)
train_acc = history.history['accuracy']
train_loss = history.history['loss']
val_acc = history.history['val_accuracy']
val_loss = history.history['val_loss']
fig.set_size_inches(20,10)

ax[0].plot(epochs , train_acc , 'go-' , label = 'Training Accuracy')
ax[0].plot(epochs , val_acc , 'ro-' , label = 'Validation Accuracy')
ax[0].set_title('Training & Validation Accuracy')
ax[0].legend()
ax[0].set_xlabel("Epochs")
ax[0].set_ylabel("Accuracy")

ax[1].plot(epochs , train_loss , 'g-o' , label = 'Training Loss')
ax[1].plot(epochs , val_loss , 'r-o' , label = 'Validation Loss')
ax[1].set_title('Testing Accuracy & Loss')
ax[1].legend()
ax[1].set_xlabel("Epochs")
ax[1].set_ylabel("Training & Validation Loss")
plt.show()

# %%
predictions = (model.predict(x_test) > 0.5).astype("int32")
predictions = predictions.reshape(1,-1)[0]
print(classification_report(y_test, predictions, target_names = ['Pneumonia (Class 0)','Normal (Class 1)']))
# Out:
#                      precision    recall  f1-score   support
#
# Pneumonia (Class 0)       0.98      0.96      0.97       842
#    Normal (Class 1)       0.91      0.95      0.93       330
#
#            accuracy                           0.96      1172
#           macro avg       0.95      0.96      0.95      1172
#        weighted avg       0.96      0.96      0.96      1172

# %%
from sklearn.metrics import f1_score
f1_score(y_test, predictions)
# Out:
# 0.9317507418397627

# %%
cm = confusion_matrix(y_test,predictions)
cm = pd.DataFrame(cm , index = ['0','1'] , columns = ['0','1'])
plt.figure(figsize = (10,10))
sns.heatmap(cm, cmap= "Blues", linecolor = 'black' , 
            linewidth = 1 , annot = True, fmt='',xticklabels = labels,yticklabels = labels)
plt.xlabel('predicted label')
plt.ylabel('true label')
# Out:
# Text(69.0, 0.5, 'true label')

# %%
import sklearn.metrics as metrics
# calculate the fpr and tpr for all thresholds of the classification
probs = (model.predict(x_test) )
probs=predictions = (model.predict(x_test) > 0.5).astype("int32")
#predictions = predictions.reshape(1,-1)[0]
preds = probs[:,]
fpr, tpr, threshold = metrics.roc_curve(y_test, preds)
roc_auc = metrics.auc(fpr, tpr)

# method I: plt
import matplotlib.pyplot as plt
plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()
